# %%
api_key = "Enter Key Here"

# %%
import openai
import jsonschema
from openai import OpenAI
client = OpenAI(api_key = api_key)
false = False
true = True

# %%
from openai import OpenAI

def extract_job_requirements(job_descriptions):
    client = OpenAI(api_key = api_key)
    json_responses = []

    # Iterate over each job description
    for description in job_descriptions:
        response = client.chat.completions.create(
            model="gpt-4o-2024-08-06",
            messages=[
                {
                    "role": "system",
                    "content": [
                        {
                            "type": "text",
                            "text": "You are a tool used to extract the requirements from a job description. I will be inputting a series of job descriptions, so please use the following prompt:\n\nFirst, extract the technical skill requirements from the job description as JSON by following these steps:\nStep 1 - Technical skills should be defined as: Specific abilities that relate to the use of tools, technologies, programming languages, software applications, or technical processes.\nStep 2 - Locate the requirements, qualifications, prerequisite, or a similar section of the job description and identify the technical skills that are explicitly stated. Do not include soft skills, experience requirements, or responsibilities.\nStep 3 - Store each of the technical skills in a key called 'skill_name' under an object called “Technical_skills”.\nStep 4 - If any technical skills are listed under responsibilities in the job description remove them.\nStep 5 - When extracting technical skills, when multiple skills are connected by 'including', 'like', or 'or' the skills should be grouped in one array to reflect that they belong to a single skill category. For example 'Experience with data management using SQL Server, Oracle, or MongoDB' should be represented as [data management, SQL Server, Oracle, MongoDB]. 'Knowledge of database systems including MySQL, PostgreSQL, and Redis' should be grouped as [database systems, MySQL, PostgreSQL, Redis].\nStep 6 -  If technical skills are listed independently without grouping indicators such as parentheses or connectors like 'including,' 'like,' or 'or,' treat each skill as separate. When no clear grouping is implied, list each skill individually rather than in an array. For example phrases 'skills required: SQL Server, Oracle, MongoDB', 'experience with SQL Server, Oracle, and MongoDB are needed' or 'understanding of SQL Server, Oracle, and MongoDB' should extract SQL Server, Oracle, and MongoDB as separate skill names.\nStep 7 - Classify each of the technical skills that are described as mandatory, essential, needed, or similar as ‘Required’. Classify the technical skills that are described as preferred, nice to have, or similar as ‘Preferred’. If a qualification is not mentioned, then the skill should be classified as ‘Preferred’. Separate the skills under two objects called ‘Required’ and ‘Preferred’.\nStep 8 - For each skill, extract the minimum years required explicitly stated for that specific skill (not inferred or through association) and list 0 if years are not explicitly stated for that specific skill. If a range of years is given, use the smallest year. Label these using a key called ‘minyears’.\nStep 9 - If any two technical skills you have extracted are extremely similar, merge them into a single skill_name array.\n\nNext, extract the required level of education from the job description as JSON by following these steps:\nStep 1 - Locate the requirements, qualifications, prerequisite, or a similar section of the job description and identify any educational requirements that are explicitly stated.\nStep 2 - Create a key called ‘education_level’ that lists the levels of education mentioned in the job qualifications. Categorize the levels of education under one of the following values that fits best: High School Diploma, Bachelor’s, Master’s, Doctorate, Postdoctorate, Vocational, None.\nStep 3 - Classify the levels of education that are explicitly described as mandatory, essential, required, or similar as ‘Required’. Classify the levels of education that are explicitly described as preferred, nice to have, or similar as ‘Preferred’. If a qualification is not mentioned, then the skill should be classified as ‘Preferred’. Separate these levels of education under two objects called ‘Required’ and ‘Preferred’.\nStep 4 - For each level of education in the list, identify and include any fields of study mentioned in a key called ‘field_of_study’ as separate values in an array. If terms like  'or similar', 'or equivalent', or 'or related' are used, include ‘Related’ as a field of study. If no fields of study are listed then do not list anything. For example 'Computer science, STEM, or related field' should be listed as [‘Computer Science’, ‘STEM’, ‘Related’].\n\nNext extract any required credentials, certifications, licenses, or similar credentials from the job description as JSON by following these steps:\nStep 1 - Search within the job description for certifications, licenses, security clearances, or similar qualifications.\nStep 2 - Extract the names of any certifications, licenses, security clearances, or similar credentials that are explicitly stated under keys called ‘credential’.\nStep 3 - If multiple options are acceptable, place them in an array under the credential. For example, if the description mentions 'Certified as IAT or IAM Level III' use ['IAM Level III Certification', 'IAT Level III Certification'].\nStep 4 - Classify each of these credentials that are explicitly described as mandatory, essential, required, or similar as ‘Required’. Classify the credentials that are explicitly described as preferred, nice to have, or similar as ‘Preferred’. If a qualification is not mentioned, then the credential should be classified as ‘Preferred’. Separate these credentials under two objects called ‘Required’ and ‘Preferred’.\nStep 5 - The output should be structured under the key ‘Credentials’, under objects for ‘Required’ and ‘Preferred’.\n\nNext, extract the required experience from the job description as JSON by following these steps:\nStep 1 - Experience is defined as: The amount and type of prior work experience a candidate must have in order to qualify for the job. This includes the level of seniority and  industry background. This does not include descriptions of responsibilities.\nStep 2 - Locate the requirements, qualifications, prerequisites, or a similar section of the job description and identify any experience requirements that are explicitly stated. \nStep 3 - Create a key for each experience requirement under a key called 'experience_desc'. \nStep 4 - If multiple experiences are grouped within parentheses or introduced by terms such as 'including', 'like', or 'or' then list them in an array and treat them as one. For example, phrases like 'including leading teams, managing projects, or consulting' should be listed as [leading teams, managing projects, consulting]. Phrases like 'leadership experience (manager, director, or VP)' should be listed as [manager, director, VP].\nStep 5 - If terms like 'or similar', 'or equivalent', or 'or related' are used, include ‘Related’ in the array.  For example, phrases like 'experience as a data scientist or related role' should be listed as [data scientist, Related].\nStep 6 - If there are any experiences that are listed under responsibilities in the job description remove them.\nStep 7 - If any experiences listed are similar to a technical skill requirement remove them. \nStep 8 - Classify each of the experiences that are explicitly described as mandatory, essential, required, or similar as ‘Required’. Classify the experiences that are explicitly described as preferred, nice to have, or similar as ‘Preferred’. If a qualification is not mentioned, then the experience should be classified as ‘Preferred’. Separate these experiences under two objects called ‘Required’ and ‘Preferred’.\nStep 8 - For each experience, list the minimum years of experience explicitly specified for that experience and list 0 if years are not explicitly specified. If a range is given, give the smallest year. Label these using a key called ‘minyears’.\n\nLastly, clean and organize the extracted requirements by following these steps:\nStep 1 - Combine the JSON outputs from skills, education, credentials, and experience into one JSON. \nStep 2 - Organize the data under two main objects: 'Required' and 'Preferred', moving the respective skills, education, credentials, and experience under them accordingly. \nStep 3 - Output the combined JSON."
                        }
                    ]
                },
                {
                    "role": "user",
                    "content": description
                }
            ],
            temperature=0.1,
            max_tokens=3200,
            top_p=0.9,
            frequency_penalty=0,
            presence_penalty=0,
            response_format={
                "type": "json_schema",
                "json_schema": {
                    "name": "job_requirements",
                    "strict": True,
                    "schema": {
                        "type": "object",
                        "properties": {
                            "Required": {
                                "type": "object",
                                "properties": {
                                    "Technical_skills": {"type": "array", "items": {"type": "object", "properties": {"skill_name": {"anyOf": [{"type": "string"}, {"type": "array", "items": {"type": "string"}}]}, "minyears": {"type": "integer"}}, "required": ["skill_name", "minyears"], "additionalProperties": False}},
                                    "Education": {"type": "array", "items": {"type": "object", "properties": {"education_level": {"type": "string"}, "field_of_study": {"type": "array", "items": {"type": "string"}}}, "required": ["education_level", "field_of_study"], "additionalProperties": False}},
                                    "Credentials": {"type": "array", "items": {"type": "object", "properties": {"credential": {"anyOf": [{"type": "string"}, {"type": "array", "items": {"type": "string"}}]}}, "required": ["credential"], "additionalProperties": False}},
                                    "Experience": {"type": "array", "items": {"type": "object", "properties": {"experience_desc": {"anyOf": [{"type": "string"}, {"type": "array", "items": {"type": "string"}}]}, "minyears": {"type": "integer"}}, "required": ["experience_desc", "minyears"], "additionalProperties": False}}
                                },
                                "required": ["Technical_skills", "Education", "Credentials", "Experience"],
                                "additionalProperties": False
                            },
                            "Preferred": {
                                "type": "object",
                                "properties": {
                                    "Technical_skills": {"type": "array", "items": {"type": "object", "properties": {"skill_name": {"anyOf": [{"type": "string"}, {"type": "array", "items": {"type": "string"}}]}, "minyears": {"type": "integer"}}, "required": ["skill_name", "minyears"], "additionalProperties": False}},
                                    "Education": {"type": "array", "items": {"type": "object", "properties": {"education_level": {"type": "string"}, "field_of_study": {"type": "array", "items": {"type": "string"}}}, "required": ["education_level", "field_of_study"], "additionalProperties": False}},
                                    "Credentials": {"type": "array", "items": {"type": "object", "properties": {"credential": {"anyOf": [{"type": "string"}, {"type": "array", "items": {"type": "string"}}]}}, "required": ["credential"], "additionalProperties": False}},
                                    "Experience": {"type": "array", "items": {"type": "object", "properties": {"experience_desc": {"anyOf": [{"type": "string"}, {"type": "array", "items": {"type": "string"}}]}, "minyears": {"type": "integer"}}, "required": ["experience_desc", "minyears"], "additionalProperties": False}}
                                },
                                "required": ["Technical_skills", "Education", "Credentials", "Experience"],
                                "additionalProperties": False
                            }
                        },
                        "required": ["Required", "Preferred"],
                        "additionalProperties": False
                    }
                }
            }
        )

        # Append only the JSON content to the list
        json_responses.append(response.choices[0].message.content)

    return json_responses

# %%
job_descriptions = [
    # Previous job descriptions here...
    """
    **Position:** Senior Cybersecurity Analyst  
    **Location:** Dahlgren, Virginia & Fredericksburg, Virginia  
    **Telework:** Hybrid telework  
    **Clearance Required:** Secret (U.S. Citizenship required)  
    **Experience Level:** Senior (7-10 years)  
    **Number of Openings:** 1  
    **Funding Status:** Future Funded  
    **Salary Range:** $120,000 - $160,000 (see below for additional details)

    **Company Overview:**  
    SimVentions, recognized as one of Virginia's Best Places to Work, is seeking a dedicated Cybersecurity Analyst to join our team. This role involves developing Risk Management Framework (RMF) Assessment & Authorization (A&A) packages, performing system testing, continuous monitoring, and related cybersecurity tasks.

    **Key Responsibilities:**  
    - Develop Assessment and Authorization (A&A) packages for various systems using the RMF process.
    - Create and maintain security documentation, including:  
      - Authorization Boundary Diagram  
      - System Hardware/Software/Information Flow  
      - System Security Plan  
      - Privacy Impact Assessment  
      - E-Authentication Implementation Plan  
      - System Level Continuous Monitoring Plan  
      - Ports, Protocols, and Services Registration  
      - Plan of Action and Milestones (POA&M)  
      - Annual FISMA Assessment  
    - Perform continuous monitoring of authorized systems.
    - Generate and update test plans; conduct system component testing using ACAS/Nessus Vulnerability Scans, STIGs, and IAVM reviews.
    - Analyze Nessus vulnerability scan results and assist with documenting findings in the POA&M.
    - Review DISA Security Technical Implementation Guide (STIG) test results and document open findings.

    **Required Qualifications:**  
    - Minimum of 7 years of experience in engineering and securing DoD systems.
    - Certified as IAT or IAM Level III.
    - In-depth understanding of computer security, military system specifications, and DoD Information Assurance policies.
    - Proven ability to communicate effectively in both written and oral formats.
    - Experience with NAVSEA Risk Management Framework Process.
    - Skilled in reviewing NESSUS vulnerability scans and STIG test results.
    - Experience in self-assessing RMF Security Controls.
    - Strong interpersonal skills and the ability to provide direct customer support.

    **Preferred Qualifications:**  
    - Navy Qualified Validator credential is a plus.

    **Educational Requirements:**  
    - Bachelor’s degree in a technical or cybersecurity-related field is preferred but not required.

    **Clearance Requirements:**  
    - Secret Clearance is required. Applicants will undergo a security investigation and must meet eligibility requirements for access to classified information. U.S. Citizenship is required to obtain clearance.
    """
]

# %%
# Call the function to process all descriptions and get only JSON outputs
results = extract_job_requirements(job_descriptions)

# Print each result JSON for review
for result in results:
    print(result)
# Out:
# {"Required":{"Technical_skills":[{"skill_name":"NAVSEA Risk Management Framework Process","minyears":0},{"skill_name":"NESSUS vulnerability scans","minyears":0},{"skill_name":"STIG test results","minyears":0},{"skill_name":"RMF Security Controls","minyears":0}],"Education":[],"Credentials":[{"credential":["IAM Level III","IAT Level III"]},{"credential":"Secret Clearance"}],"Experience":[{"experience_desc":"engineering and securing DoD systems","minyears":7}]},"Preferred":{"Technical_skills":[],"Education":[{"education_level":"Bachelor’s","field_of_study":["Technical","Cybersecurity","Related"]}],"Credentials":[{"credential":"Navy Qualified Validator"}],"Experience":[]}}
